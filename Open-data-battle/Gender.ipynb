# %% [markdown]
# В одной компании произошла неприятность: случился потоп, в бумажных анкетах клиентов размыло некоторые строки и в 1000 анкетах пострадало поле “gender”. Конечно, их было бы можно восстановить, но в компании решили автоматизировать решение проблемы и определить пол клиентов по фотографиям. Был создан датасет gender.csv, в котором записаны признаки человека на фото и его пол.
#
# Первые 1000 значений имеют пропуски в столбце gender.
#
# Все столбцы с ".1" в названии дублируют предыдущие столбцы без ".1", но содержат уникальные значения
#
# Необходимо произвести чистку данных:
#
# Присоединить дублирующие столбцы к основным.
# Столбцы 'nose_wide', 'nose_long', 'lips_thin', 'distance_nose_to_lip_long', 'long_hair' содержат информацию в условных единицах. Известно, что измерения проводились разными людьми с разными измерительными инструментами, поэтому данные в столбцах имеют разную погрешность измерений. Необходимо уменьшить влияние погрешности путем приравнивания значений диапазона [0,0.5) к 0, а [0.5, 1) —- к 1. Столбцы 'orehead_width_cm' и 'forehead_height_cm' необходимо оставить «как есть».
# Оставить один из дублирующих друг друга столбцов.
# Определите пол по остальным параметрам из выборки для первой тысячи значений и прикрепите его в CSV формате. Файл должен содержать только прогнозные значения в формате "Male"/"Female", в одном столбце без заголовка
#
# Пороговое значение для данной задачи классификации считать равным 0.5.
#
# Для успешного прохождения достаточно иметь 70% точность решения

# %%
import pandas as pd
# %run pipeline.ipynb

# %%
df=pd.read_csv('datasets/gender.csv')
df.head()
# Out:
#    Unnamed: 0  index  long_hair  forehead_width_cm  forehead_height_cm  \
# 0           0      0   0.704275               11.8                 6.1
# 1           1      1   0.118690               14.0                 5.4
# 2           2      2   0.203894               11.8                 6.3
# 3           3      3   0.386228               14.4                 6.1
# 4           4      4   0.564020               13.5                 5.9
#
#    forehead_width_mm  forehead_width_conventional_units  nose_wide  nose_long  \
# 0              118.0                           0.025806   0.895614   0.477485
# 1              140.0                           0.167742   0.202520   0.186825
# 2              118.0                           0.025806   0.892793   0.723152
# 3              144.0                           0.193548   0.024963   0.562005
# 4              135.0                           0.135484   0.415389   0.063705
#
#    lips_thin  ...  long_hair.1 forehead_width_cm.1  forehead_height_cm.1  \
# 0   0.841261  ...     0.818018                11.5                   5.8
# 1   0.719697  ...     0.995941                15.2                   5.8
# 2   0.725821  ...     0.633806                15.4                   5.7
# 3   0.831515  ...     0.795792                13.0                   6.9
# 4   0.211584  ...     0.915185                14.2                   5.8
#
#    forehead_width_mm.1  forehead_width_conventional_units.1  nose_wide.1  \
# 0                115.0                             0.006452     0.137806
# 1                152.0                             0.245161     0.570656
# 2                154.0                             0.258065     0.709777
# 3                130.0                             0.103226     0.883454
# 4                142.0                             0.180645     0.652973
#
#    nose_long.1  lips_thin.1  distance_nose_to_lip_long.1  gender.1
# 0     0.402620     0.167844                     0.188913    Female
# 1     0.980237     0.811487                     0.967540      Male
# 2     0.365825     0.933026                     0.646992      Male
# 3     0.399733     0.595028                     0.822491      Male
# 4     0.735543     0.553571                     0.532910      Male
#
# [5 rows x 23 columns]

# %%
pipe.info.getInfo(df)
# Out:
#                                     DataType  Values  Null Missing Rate  \
# Unnamed: 0                             int64    2515     0        0.00%
# index                                  int64    2515     0        0.00%
# long_hair                            float64    2515     0        0.00%
# forehead_width_cm                    float64    2515     0        0.00%
# forehead_height_cm                   float64    2515     0        0.00%
# forehead_width_mm                    float64    2515     0        0.00%
# forehead_width_conventional_units    float64    2515     0        0.00%
# nose_wide                            float64    2515     0        0.00%
# nose_long                            float64    2515     0        0.00%
# lips_thin                            float64    2515     0        0.00%
# distance_nose_to_lip_long            float64    2515     0        0.00%
# gender                                object    1514  1001       39.80%
# index.1                                int64    2515     0        0.00%
# long_hair.1                          float64    2486    29        1.15%
# forehead_width_cm.1                  float64    2486    29        1.15%
# forehead_height_cm.1                 float64    2486    29        1.15%
# forehead_width_mm.1                  float64    2486    29        1.15%
# forehead_width_conventional_units.1  float64    2486    29        1.15%
# nose_wide.1                          float64    2486    29        1.15%
# nose_long.1                          float64    2486    29        1.15%
# lips_thin.1                          float64    2486    29        1.15%
# distance_nose_to_lip_long.1          float64    2486    29        1.15%
# gender.1                              object    2486    29        1.15%
#
#                                      Unique  Useless
# Unnamed: 0                             2515     True
# index                                  2515     True
# long_hair                              2515    False
# forehead_width_cm                        42    False
# forehead_height_cm                       21    False
# forehead_width_mm                        42    False
# forehead_width_conventional_units        42    False
# nose_wide                              2515    False
# nose_long                              2515    False
# lips_thin                              2515    False
# distance_nose_to_lip_long              2515    False
# gender                                    2    False
# index.1                                2515    False
# long_hair.1                            2486    False
# forehead_width_cm.1                      42    False
# forehead_height_cm.1                     21    False
# forehead_width_mm.1                      42    False
# forehead_width_conventional_units.1      42    False
# nose_wide.1                            2486    False
# nose_long.1                            2486    False
# lips_thin.1                            2486    False
# distance_nose_to_lip_long.1            2486    False
# gender.1                                  2    False

# %% [markdown]
# Присоединим столбцы

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'index', 'long_hair', 'forehead_width_cm',
#        'forehead_height_cm', 'forehead_width_mm',
#        'forehead_width_conventional_units', 'nose_wide', 'nose_long',
#        'lips_thin', 'distance_nose_to_lip_long', 'gender', 'index.1',
#        'long_hair.1', 'forehead_width_cm.1', 'forehead_height_cm.1',
#        'forehead_width_mm.1', 'forehead_width_conventional_units.1',
#        'nose_wide.1', 'nose_long.1', 'lips_thin.1',
#        'distance_nose_to_lip_long.1', 'gender.1'],
#       dtype='object')

# %%
for col in ['long_hair', 'forehead_width_cm',
            'forehead_height_cm', 'forehead_width_mm',
            'forehead_width_conventional_units', 'nose_wide', 'nose_long',
            'lips_thin', 'distance_nose_to_lip_long']:
    df[col]=(df[col]+df[col+'.1'])/2

# %%
for col in ['nose_wide', 'nose_long', 'lips_thin', 'distance_nose_to_lip_long', 'long_hair']:
    df[col]=(df[col]<0.5).astype('int')
df.columns
# Out:
# Index(['Unnamed: 0', 'index', 'long_hair', 'forehead_width_cm',
#        'forehead_height_cm', 'forehead_width_mm',
#        'forehead_width_conventional_units', 'nose_wide', 'nose_long',
#        'lips_thin', 'distance_nose_to_lip_long', 'gender', 'index.1',
#        'long_hair.1', 'forehead_width_cm.1', 'forehead_height_cm.1',
#        'forehead_width_mm.1', 'forehead_width_conventional_units.1',
#        'nose_wide.1', 'nose_long.1', 'lips_thin.1',
#        'distance_nose_to_lip_long.1', 'gender.1'],
#       dtype='object')

# %%
df=df.drop(columns=['index.1',
       'long_hair.1', 'forehead_width_cm.1', 'forehead_height_cm.1',
       'forehead_width_mm.1', 'forehead_width_conventional_units.1',
       'nose_wide.1', 'nose_long.1', 'lips_thin.1',
       'distance_nose_to_lip_long.1'])

# %%
df_p = df[:1001].copy()
df_p
# Out:
#       Unnamed: 0  index  long_hair  forehead_width_cm  forehead_height_cm  \
# 0              0      0          0              11.65                5.95
# 1              1      1          0              14.60                5.60
# 2              2      2          1              13.60                6.00
# 3              3      3          0              13.70                6.50
# 4              4      4          0              13.85                5.85
# ...          ...    ...        ...                ...                 ...
# 996          996    996          0              12.05                5.95
# 997          997    997          0              13.90                5.65
# 998          998    998          0              13.05                6.50
# 999          999    999          0              14.20                6.00
# 1000        1000   1000          0              13.40                5.55
#
#       forehead_width_mm  forehead_width_conventional_units  nose_wide  \
# 0                 116.5                           0.016129          0
# 1                 146.0                           0.206452          1
# 2                 136.0                           0.141935          0
# 3                 137.0                           0.148387          1
# 4                 138.5                           0.158065          0
# ...                 ...                                ...        ...
# 996               120.5                           0.041935          1
# 997               139.0                           0.161290          1
# 998               130.5                           0.106452          0
# 999               142.0                           0.180645          1
# 1000              134.0                           0.129032          0
#
#       nose_long  lips_thin  distance_nose_to_lip_long gender gender.1
# 0             1          0                          0    NaN   Female
# 1             0          0                          0    NaN     Male
# 2             0          0                          0    NaN     Male
# 3             1          0                          0    NaN     Male
# 4             1          1                          1    NaN     Male
# ...         ...        ...                        ...    ...      ...
# 996           1          1                          0    NaN   Female
# 997           1          0                          1    NaN   Female
# 998           0          0                          0    NaN     Male
# 999           1          1                          0    NaN   Female
# 1000          0          0                          1    NaN   Female
#
# [1001 rows x 13 columns]

# %%
df_t=df[1001:].copy()
df_t
# Out:
#       Unnamed: 0  index  long_hair  forehead_width_cm  forehead_height_cm  \
# 1001        1001   1001          0              13.10                5.90
# 1002        1002   1002          0              12.65                6.10
# 1003        1003   1003          0              13.70                5.85
# 1004        1004   1004          0              13.35                6.50
# 1005        1005   1005          0              13.25                5.70
# ...          ...    ...        ...                ...                 ...
# 2510        2510   2510          0              13.75                5.75
# 2511        2511   2511          0              12.85                5.25
# 2512        2512   2512          0              12.55                5.50
# 2513        2513   2513          0              12.65                5.70
# 2514        2514   2514          0              13.80                5.60
#
#       forehead_width_mm  forehead_width_conventional_units  nose_wide  \
# 1001              131.0                           0.109677          0
# 1002              126.5                           0.080645          0
# 1003              137.0                           0.148387          0
# 1004              133.5                           0.125806          0
# 1005              132.5                           0.119355          1
# ...                 ...                                ...        ...
# 2510              137.5                           0.151613          0
# 2511              128.5                           0.093548          0
# 2512              125.5                           0.074194          1
# 2513              126.5                           0.080645          1
# 2514              138.0                           0.154839          0
#
#       nose_long  lips_thin  distance_nose_to_lip_long  gender gender.1
# 1001          0          0                          0    Male     Male
# 1002          0          0                          0    Male     Male
# 1003          1          0                          1  Female     Male
# 1004          0          0                          1  Female     Male
# 1005          1          0                          1  Female   Female
# ...         ...        ...                        ...     ...      ...
# 2510          0          1                          1    Male   Female
# 2511          0          1                          0    Male   Female
# 2512          1          1                          1  Female   Female
# 2513          1          0                          0    Male   Female
# 2514          0          0                          0    Male     Male
#
# [1514 rows x 13 columns]

# %%
df_t.drop(columns='gender.1', inplace=True)

# %%
df_t=df_t[['long_hair', 'forehead_width_cm',
            'forehead_height_cm', 'forehead_width_mm',
            'forehead_width_conventional_units', 'nose_wide', 'nose_long',
            'lips_thin', 'distance_nose_to_lip_long','gender']]
df_t
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  forehead_width_mm  \
# 1001          0              13.10                5.90              131.0
# 1002          0              12.65                6.10              126.5
# 1003          0              13.70                5.85              137.0
# 1004          0              13.35                6.50              133.5
# 1005          0              13.25                5.70              132.5
# ...         ...                ...                 ...                ...
# 2510          0              13.75                5.75              137.5
# 2511          0              12.85                5.25              128.5
# 2512          0              12.55                5.50              125.5
# 2513          0              12.65                5.70              126.5
# 2514          0              13.80                5.60              138.0
#
#       forehead_width_conventional_units  nose_wide  nose_long  lips_thin  \
# 1001                           0.109677          0          0          0
# 1002                           0.080645          0          0          0
# 1003                           0.148387          0          1          0
# 1004                           0.125806          0          0          0
# 1005                           0.119355          1          1          0
# ...                                 ...        ...        ...        ...
# 2510                           0.151613          0          0          1
# 2511                           0.093548          0          0          1
# 2512                           0.074194          1          1          1
# 2513                           0.080645          1          1          0
# 2514                           0.154839          0          0          0
#
#       distance_nose_to_lip_long  gender
# 1001                          0    Male
# 1002                          0    Male
# 1003                          1  Female
# 1004                          1  Female
# 1005                          1  Female
# ...                         ...     ...
# 2510                          1    Male
# 2511                          0    Male
# 2512                          1  Female
# 2513                          0    Male
# 2514                          0    Male
#
# [1514 rows x 10 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df_t.drop(columns='gender'), (df_t['gender']=='Male').astype('int'), test_size=0.25, random_state=111)

# %%
#pipe.models.compare_model(pipe.models._get_classification_model_list(),X_train,y_train, scoring='precision')

# %%
model = LogisticRegression(random_state=5888)
model.fit(X_train,y_train)
prediction = model.predict(X_test)
# Out:
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,prediction)
# Out:
# 0.7255936675461742

# %%
model.fit(df_t.drop(columns='gender'),df_t['gender'])
# Out:
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# LogisticRegression(random_state=5888)

# %%
df_p=df_p[['long_hair', 'forehead_width_cm',
            'forehead_height_cm', 'forehead_width_mm',
            'forehead_width_conventional_units', 'nose_wide', 'nose_long',
            'lips_thin', 'distance_nose_to_lip_long','gender']]
df_p=df_p.drop(columns='gender')
df_p
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  forehead_width_mm  \
# 0             0              11.65                5.95              116.5
# 1             0              14.60                5.60              146.0
# 2             1              13.60                6.00              136.0
# 3             0              13.70                6.50              137.0
# 4             0              13.85                5.85              138.5
# ...         ...                ...                 ...                ...
# 996           0              12.05                5.95              120.5
# 997           0              13.90                5.65              139.0
# 998           0              13.05                6.50              130.5
# 999           0              14.20                6.00              142.0
# 1000          0              13.40                5.55              134.0
#
#       forehead_width_conventional_units  nose_wide  nose_long  lips_thin  \
# 0                              0.016129          0          1          0
# 1                              0.206452          1          0          0
# 2                              0.141935          0          0          0
# 3                              0.148387          1          1          0
# 4                              0.158065          0          1          1
# ...                                 ...        ...        ...        ...
# 996                            0.041935          1          1          1
# 997                            0.161290          1          1          0
# 998                            0.106452          0          0          0
# 999                            0.180645          1          1          1
# 1000                           0.129032          0          0          0
#
#       distance_nose_to_lip_long
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             1
# ...                         ...
# 996                           0
# 997                           1
# 998                           0
# 999                           0
# 1000                          1
#
# [1001 rows x 9 columns]

# %%
df_p['forehead_width_cm'].fillna(df_p['forehead_width_cm'].median(), inplace=True)
df_p['forehead_height_cm'].fillna(df_p['forehead_width_cm'].median(), inplace=True)
df_p['forehead_width_mm'].fillna(df_p['forehead_width_cm'].median(), inplace=True)
df_p['forehead_width_conventional_units'].fillna(df_p['forehead_width_cm'].median(), inplace=True)
prediction = model.predict(df_p)

# %%
pd.DataFrame(prediction).to_csv('gender.csv', header=False, index=False)
