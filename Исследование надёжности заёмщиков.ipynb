# %% [markdown]
# # Исследование надёжности заёмщиков
#
# Заказчик — кредитный отдел банка. Нужно разобраться, влияет ли семейное положение и количество детей клиента на факт погашения кредита в срок. Входные данные от банка — статистика о платёжеспособности клиентов.
#
# Результаты исследования будут учтены при построении модели **кредитного скоринга** — специальной системы, которая оценивает способность потенциального заёмщика вернуть кредит банку.

# %%
# %run Pipeline.ipynb
data=pd.read_csv('datasets/credits.csv')
pipe.info.getInfo(data)
# Out:
#                  DataType  Values  Null Missing Rate  Unique  Useless
# children            int64   21525     0        0.00%       8    False
# days_employed     float64   19351  2174       11.23%   19351    False
# dob_years           int64   21525     0        0.00%      58    False
# education          object   21525     0        0.00%      15    False
# education_id        int64   21525     0        0.00%       5    False
# family_status      object   21525     0        0.00%       5    False
# family_status_id    int64   21525     0        0.00%       5    False
# gender             object   21525     0        0.00%       3    False
# income_type        object   21525     0        0.00%       8    False
# debt                int64   21525     0        0.00%       2    False
# total_income      float64   19351  2174       11.23%   19351    False
# purpose            object   21525     0        0.00%      38    False

# %%
print(f'Категориальные переменные {pipe.info.getCatCol(data)}')
# Out:
# Категориальные переменные Index(['education', 'family_status', 'gender', 'income_type', 'purpose'], dtype='object')

# %%
print(f'Кколичественные переменные {pipe.info.getNumCol(data)}')
# Out:
# Кколичественные переменные Index(['children', 'days_employed', 'dob_years', 'education_id',
#        'family_status_id', 'debt', 'total_income'],
#       dtype='object')

# %% [markdown]
# #### Анализ данных

# %%
data.groupby('children')['children'].count()
display(data[data['children']==-1].sample(n=10))
display(data[data['children']==20].sample(n=10))
# Out:
#        children  days_employed  dob_years education  education_id  \
# 7190         -1   -5928.202068         34   СРЕДНЕЕ             1
# 6385         -1  370215.476226         48   среднее             1
# 4201         -1    -901.101738         41   среднее             1
# 19417        -1  350340.760224         28   среднее             1
# 16129        -1    -457.861760         33   среднее             1
# 21140        -1   -1422.668059         44   среднее             1
# 10918        -1  340499.039342         50   среднее             1
# 5272         -1   -1143.485347         46   среднее             1
# 11268        -1   -1048.782203         30    высшее             0
# 941          -1            NaN         57   Среднее             1
#
#           family_status  family_status_id gender  income_type  debt  \
# 7190    женат / замужем                 0      M    сотрудник     0
# 6385     вдовец / вдова                 2      F    пенсионер     0
# ...
